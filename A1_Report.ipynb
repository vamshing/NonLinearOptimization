# %% [markdown]
# ## OR506-Home Work 1
# ** Created on iPython Notebook by **
# **Guduguntla Vamshi**
# **<gudugu@ncsu.edu>**

# %% [markdown]
# ***1.***
# \begin{equation}
#   f(x,y) = 4x^4-12x^3y+13x^2y^2-6xy^3+y^4
# \end{equation}

# %% [markdown]
# **a) Compute ∇f(0,0)**

# %% [markdown]
# \begin{eqnarray}
#    \ ∇f(0,0) =
#     \begin{pmatrix}
#   df/dx \\
#   df/dy \\
#  \end{pmatrix}
#    \ at \ (x=0,y=0) \\
#    \ = \begin{pmatrix}
#    16x^3 - 36x^2y + 26xy^2 - 6y^3 \\
#    -12x^3 + 26x^2y - 18xy^2 + 4y^3 \\
#    \end{pmatrix}_{(0,0)}
#    \ = [0,0]
# \end{eqnarray}

# %% [markdown]
# **b) Compute hessian at (0,0)**

# %% [markdown]
# \begin{eqnarray}
# D^2F(x,y) &= D^2F(0,0)
# \end{eqnarray}
#
# \begin{eqnarray}
# \begin{pmatrix}
# d^2f/dx^2 & df/dxdy \\
# df/dyx & d^2f/dy^2 \\
# \end{pmatrix}_{at(x=0,y=0)} \
# \end{eqnarray}
#
#
# \begin{eqnarray}
# \ = \begin{pmatrix}
# 2(24x^2 - 36xy + 13y^2 & 12(-18x^2 + 26xy - 9y^2)\\
# 2(-18x^2 + 26xy - 9y^2)& 2(13x^2 - 18xy + 6y^2)\\
# \end{pmatrix}_{(0,0)}
# \end{eqnarray}
#
#
# \begin{eqnarray}  &=
# \begin{pmatrix}
# 0 & 0\\
# 0 & 0\\
# \end{pmatrix}
# \end{eqnarray}

# %% [markdown]
# **c) Is (0, 0) local minimizer ?**

# %% [markdown]
# - At the critical point (0, 0), the Hessian is positive semidefinite and negative semidefinite, **so
# we can’t say anything**
# - (0,0) would be a local minimizer if there is a neighbourhood of U  such that for any point x E U: f(x_{min}) <= f(x)|
# - Also,the Hessian matrix should be positive definite.
# - However,If we simuate the function over the longer interval of (x,y), we find that the (0,0) is the global minima.
# - Therefore, (0,0) is global minima and **not the local minimizer**

# %%
import numpy as np,math,matplotlib.pyplot as plt
# %matplotlib inline 
from mpl_toolkits.mplot3d import Axes3D
def fun(a,b):
    return 4*a**4 - 12*a**3*b + 13*a**2*b**2 - 6*a*b**3+ b**4
x = np.outer(np.linspace(-100, 100, 100), np.ones(100))
y = x.copy().T
z = (4*x**4 - 12*x**3*y + 13*x**2*y**2 - 6*x*y**3+ y**4)
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_surface(x, y, z, cmap=plt.cm.jet, rstride=1, cstride=1, linewidth=0)

# %% [markdown]
# **2.** Let
# \begin{equation}
# f (x, y) = 2x^2 + y^2 − 2xy + 2x^3 + x^4
# \end{equation}Find local min/max for f

# %% [markdown]
# \begin{eqnarray}
#    \ ∇f(x,y) =
# \end{eqnarray}
#
# \begin{eqnarray}
# \begin{pmatrix}
# df/dx \\
# df/dy \\
# \end{pmatrix}
# \ at \ (x,y) \\
# \end{eqnarray}
#
# \begin{eqnarray}
# \ = \begin{pmatrix}
# 4x^3 + 6x^2 + 4x - 2y \\
# -2x + 2y \\
# \end{pmatrix}_{(0,0)}
# \end{eqnarray}
#
# \begin{eqnarray}
# \ = [0,0] \\
# \  => x = y,x = 0&or(4x^2+6x+2) = 0 \\
# \ gives  \\
# \ (x,y) = (0,0)&or (-.0.5,-0.5),(-1,-1)
# \end{eqnarray}
#  Hessian matrix:
#
# \begin{eqnarray}
# D^2F(x,y) &= D^2F(0,0) &=
# \begin{pmatrix}
# d^2f/dx^2 & df/dxdy\\
# df/dyx & d^2f/dy^2\\
# \end{pmatrix}_{at(x=0,y=0)}
# \end{eqnarray}
#
# \begin{eqnarray}
# \begin{pmatrix}
# 4(3x^2 + 3x+ 1 & -2 \\
# -2 & 2 \\
# \end{pmatrix}
# \end{eqnarray}
#
# \begin{eqnarray}
# D^2F(0,0) &=
# \begin{pmatrix}
# 4 & -2\\
# -2 & 2\\
# \end{pmatrix}_{at(x=0,y=0)} \\
# \end{eqnarray}
#
# \begin{eqnarray}
# D^2F(-1,-1) &=
# \begin{pmatrix}
# 4 & -2\\
# -2 & 2\\
# \end{pmatrix}_{at(x=-1,y=-1)} \\
# \end{eqnarray}
#
# \begin{eqnarray}
# D^2F(-0.5,-0.5) &=
# \begin{pmatrix}
# 1 & -2\\
# -2 & 2\\
# \end{pmatrix}_{at(x=-0.5,y=-0.5)} \\
# \end{eqnarray}
#
# Using the Second-order conditions:
#
# \begin{eqnarray}
# D^2F(0,0)&is&positive&definite&(4.2 - 2^2 > 0) \\
# => (0,0)&is&strict&local&minima \\
# \end{eqnarray}
#
# \begin{eqnarray}
# D^2F(-1,-1)&is&positive&definite&(4.2 - 2^2 > 0) \\
# => (-1,-1)&is&strict&local&minima \\
# \end{eqnarray}
#
# \begin{eqnarray}
# D^2F(-0.5,-0.5)&is&negative&definite&(2 - 2^2 < 0) \\
# => (-0.5,-0.5)&is&strict&local&maxima \\
# \end{eqnarray}
